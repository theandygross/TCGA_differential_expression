# %%
import NotebookImport
from Imports import *
# Out:
# importing IPython notebook from Imports.ipynb
# Populating the interactive namespace from numpy and matplotlib

# %%
paired_bp_tn_split(rna_df.ix['GRIN2B'], codes)

# %%
rna_df.ix['GRIA1'][:,'11'].groupby(codes).mean().order()
# Out:
# codes
# SKCM    -3.00
# LIHC    -1.32
# PAAD     0.04
# SARC     0.89
# PRAD     1.25
# KIRP     1.28
# KICH     1.38
# KIRC     1.39
# HNSC     1.79
# THCA     2.33
# BLCA     2.65
# CESC     2.66
# COAD     2.98
# UCEC     3.11
# READ     3.53
# PCPG     4.27
# BRCA     5.05
# LUAD     8.63
# LUSC     8.64
# dtype: float64

# %%
maf = pd.read_csv('/cellar/users/agross/TCGA_Code/CancerData/Data/MAFs_new_2/meta.csv',
                  index_col=['Hugo_Symbol','Tumor_Sample_Barcode'])['0']
maf = maf.unstack().fillna(0)

# %%
maf = FH.fix_barcode_columns(maf)
maf = maf.xs('01',1,1)

# %%
df = maf.ix[['GRIA1','GRIA2','GRIA3','GRIA4','GRIN1','GRIN2A','GRIN2B']]

# %%
violin_plot_pandas(df.ix['GRIA1']>0, rna_df.ix['GRIA1'][:,'01'])

# %%
violin_plot_pandas(df.ix['GRIA2']>0, rna_df.ix['GRIA2'][:,'01'])

# %%
violin_plot_pandas(df.ix['GRIA3']>0, rna_df.ix['GRIA3'][:,'01'])

# %%
violin_plot_pandas(df.ix['GRIA4']>0, rna_df.ix['GRIA4'][:,'01'])

# %%
violin_plot_pandas(df.ix['GRIN2A']>0, rna_df.ix['GRIN2A'][:,'01'])

# %%
violin_plot_pandas(df.ix['GRIN2B']>0, rna_df.ix['GRIN2B'][:,'01'])

# %%
violin_plot_pandas(df.sum()>0, rna_df.ix['GRIN2A'][:,'01'])

# %%
df.ix['GRIN2A'].sum()
# Out:
# 437.0
